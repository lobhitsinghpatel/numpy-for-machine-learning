# %%
import numpy as np

X = np.array([
    [22, 25000, 1],
    [25, 30000, 2],
    [30, 50000, 5],
    [35, 70000, 8]
])

# 1 Add 5 to Age
X[:, 0] += 5
print(X)

# Reset dataset
X = np.array([
    [22, 25000, 1],
    [25, 30000, 2],
    [30, 50000, 5],
    [35, 70000, 8]
])

# 2 Add 5000 to Salary
X[:, 1] += 5000
print(X)

# 3 Multiply Experience by 2
X[:, 2] *= 2
print(X)

# 4 Feature Scaling Example
salary = X[:, 1]

scaled_salary = salary / 1000

print(scaled_salary)

# 5 Add Bonus
bonus = np.array([2000])

print(salary + bonus)

# %% [markdown]
# Tasks
# 1. Add 2 years to every age.
# 2. Add ₹3000 to every salary.
# 3. Multiply experience by 3.
# 4. Create a salary bonus array:
#    bonus = np.array([1000])
#    Add it to salary.
# 5. Divide every salary by 1000.
# 6. Multiply all values by 2.
# 7. Subtract 1 from every element.
# 8. Create a new column:
#    salary_per_experience
#    using broadcasting.
# 9. Find average salary after bonus.
# 10. Verify that no loops were used.

# %%
import numpy as np

X = np.array([
    [22, 25000, 1],
    [25, 30000, 2],
    [30, 50000, 5],
    [35, 70000, 8]
])

#1
X[:, 0] += 2
print(X)

#2 
X[:, 1] += 3000
print(X)

#3 
X[:, 2] *=3
print(X)

#4 
bonus = np.array([1000])
print(X[:,1] + bonus)

#5
scaled_salary = X[:, 1] / 1000
print(scaled_salary)

#6
double_dataset = X * 2
print(double_dataset)

#7
minus_one = X - 1
print(minus_one)
